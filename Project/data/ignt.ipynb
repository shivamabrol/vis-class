# %%
import pandas as pd
import numpy as np
import glob

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig')

# %%
df = pd.read_csv('combined_csv.csv')

# %%
len(df[df['County'] == 'Hamilton'])
# Out:
# 210

# %%
len(df)
# Out:
# 40551

# %%
df_hamilton = df[df['County'] == 'Hamilton']

# %%
df_hamilton
# Out:
#            State    County  Year  Days with AQI  Good Days  Moderate Days  \
# 150      Indiana  Hamilton  1985            123         60             46
# 425         Ohio  Hamilton  1985            365         30            125
# 521    Tennessee  Hamilton  1985            365        260             78
# 895      Indiana  Hamilton  1991            179        109             49
# 1192    New York  Hamilton  1991            146        134              8
# ...          ...       ...   ...            ...        ...            ...
# 39536       Ohio  Hamilton  1989            365         92            161
# 39644  Tennessee  Hamilton  1989            308        219             63
# 39997    Indiana  Hamilton  1988            207        105             50
# 40301       Ohio  Hamilton  1988            366         97            148
# 40403  Tennessee  Hamilton  1988            366        232             66
#
#        Unhealthy for Sensitive Groups Days  Unhealthy Days  \
# 150                                     13               4
# 425                                    192              17
# 521                                     22               5
# 895                                     18               3
# 1192                                     4               0
# ...                                    ...             ...
# 39536                                   89              22
# 39644                                   22               4
# 39997                                   25              25
# 40301                                   80              32
# 40403                                   44              21
#
#        Very Unhealthy Days  Hazardous Days  Max AQI  90th Percentile AQI  \
# 150                      0               0      190                  112
# 425                      1               0      210                  139
# 521                      0               0      177                   93
# 895                      0               0      166                  105
# 1192                     0               0      147                   48
# ...                    ...             ...      ...                  ...
# 39536                    1               0      205                  137
# 39644                    0               0      182                   93
# 39997                    2               0      203                  159
# 40301                    9               0      222                  161
# 40403                    3               0      210                  133
#
#        Median AQI  Days CO  Days NO2  Days Ozone  Days SO2  Days PM2.5  \
# 150            51        0         0         123         0           0
# 425           105        2        34          36       293           0
# 521            40        0         0         365         0           0
# 895            46        0         0         179         0           0
# 1192           31        0         0         141         5           0
# ...           ...      ...       ...         ...       ...         ...
# 39536          75        6        70          72       192           0
# 39644          42        0         0         289         0           0
# 39997          50        0         0         207         0           0
# 40301          79        1        86          86       192           0
# 40403          43        0         0         350         0           0
#
#        Days PM10
# 150            0
# 425            0
# 521            0
# 895            0
# 1192           0
# ...          ...
# 39536         25
# 39644         19
# 39997          0
# 40301          1
# 40403         16
#
# [210 rows x 19 columns]

# %%
df_hamilton.to_csv('hamilton.csv')
